# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os

from six.moves import urllib

import numpy as np

import tensorflow as tf
from tensorflow.contrib.learn.python.learn.estimators import model_fn as model_fn_lib

tf.logging.set_verbosity(tf.logging.INFO)

# %%
TRAINING_URL = 'http://download.tensorflow.org/data/abalone_train.csv'
TEST_URL = 'http://download.tensorflow.org/data/abalone_test.csv'
PREDICTION_URL = 'http://download.tensorflow.org/data/abalone_predict.csv'

TRAINING_FILENAME = TRAINING_URL.split('/')[-1]
TEST_FILENAME = TEST_URL.split('/')[-1]
PREDICTION_FILENAME = PREDICTION_URL.split('/')[-1]

def maybe_download(url, filename):
  if not os.path.exists(filename):
    urllib.request.urlretrieve(url, filename)
  dataset = tf.contrib.learn.datasets.base.load_csv_without_header(
    filename=filename, target_dtype=np.int, features_dtype=np.float32)
  return dataset
  
training_dataset = maybe_download(TRAINING_URL, TRAINING_FILENAME)
test_dataset = maybe_download(TEST_URL, TEST_FILENAME)
prediction_dataset = maybe_download(PREDICTION_URL, PREDICTION_FILENAME)

# %%
from tensorflow.contrib.keras.python.keras.layers import Dense

def model_fn(features, targets, mode, params):
  """Model function for Estimator."""

  first_hidden_layer = Dense(10, activation='relu')(features)
  second_hidden_layer = Dense(10, activation='relu')(first_hidden_layer)
  output_layer = Dense(1, activation='linear')(second_hidden_layer)  

  # Reshape output layer to 1-dim Tensor to return predictions
  predictions = tf.reshape(output_layer, [-1])
  predictions_dict = {"ages": predictions}

  # Calculate loss using mean squared error
  loss = tf.losses.mean_squared_error(targets, predictions)

  # Calculate root mean squared error as additional eval metric
  eval_metric_ops = {
      "rmse": tf.metrics.root_mean_squared_error(
          tf.cast(targets, tf.float32), predictions)
  }

  train_op = tf.contrib.layers.optimize_loss(
      loss=loss,
      global_step=tf.contrib.framework.get_global_step(),
      learning_rate=params["learning_rate"],
      optimizer="SGD")

  return model_fn_lib.ModelFnOps(
      mode=mode,
      predictions=predictions_dict,
      loss=loss,
      train_op=train_op,
      eval_metric_ops=eval_metric_ops)

# %%
# Learning rate for the model
LEARNING_RATE = 0.001

# Set model params
model_params = {"learning_rate": LEARNING_RATE}

# Instantiate Estimator
nn = tf.contrib.learn.Estimator(model_fn=model_fn, params=model_params)

def get_train_inputs():
  x = tf.constant(training_dataset.data)
  y = tf.constant(training_dataset.target)
  return x, y

# Fit
nn.fit(input_fn=get_train_inputs, steps=5000)

# Score accuracy
def get_test_inputs():
  x = tf.constant(test_dataset.data)
  y = tf.constant(test_dataset.target)
  return x, y

ev = nn.evaluate(input_fn=get_test_inputs, steps=1)
print("Loss: %s" % ev["loss"])
print("Root Mean Squared Error: %s" % ev["rmse"])

# Print out predictions
predictions = nn.predict(x=prediction_dataset.data, as_iterable=True)
for i, p in enumerate(predictions):
  print("Prediction %s: %s" % (i + 1, p["ages"]))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmprLAnz7
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_task_type': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0b33fd7fd0>, '_model_dir': '/tmp/tmprLAnz7', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_tf_random_seed': None, '_environment': 'local', '_num_worker_replicas': 0, '_task_id': 0, '_save_summary_steps': 100, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_evaluation_master': '', '_master': ''}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmprLAnz7/model.ckpt.
# INFO:tensorflow:loss = 109.256, step = 1
# INFO:tensorflow:global_step/sec: 644.305
# INFO:tensorflow:loss = 6.92812, step = 101 (0.158 sec)
# INFO:tensorflow:global_step/sec: 640.34
# INFO:tensorflow:loss = 6.84912, step = 201 (0.156 sec)
# INFO:tensorflow:global_step/sec: 674.359
# INFO:tensorflow:loss = 6.79257, step = 301 (0.148 sec)
# INFO:tensorflow:global_step/sec: 661.511
# INFO:tensorflow:loss = 6.73941, step = 401 (0.151 sec)
# INFO:tensorflow:global_step/sec: 685.448
# INFO:tensorflow:loss = 6.68933, step = 501 (0.146 sec)
# INFO:tensorflow:global_step/sec: 634.087
# INFO:tensorflow:loss = 6.63984, step = 601 (0.158 sec)
# INFO:tensorflow:global_step/sec: 673.918
# INFO:tensorflow:loss = 6.59075, step = 701 (0.148 sec)
# INFO:tensorflow:global_step/sec: 673.954
# INFO:tensorflow:loss = 6.53925, step = 801 (0.148 sec)
# INFO:tensorflow:global_step/sec: 655.725
# INFO:tensorflow:loss = 6.48481, step = 901 (0.153 sec)
# INFO:tensorflow:global_step/sec: 677.089
# INFO:tensorflow:loss = 6.42813, step = 1001 (0.148 sec)
# INFO:tensorflow:global_step/sec: 556.421
# INFO:tensorflow:loss = 6.37147, step = 1101 (0.180 sec)
# INFO:tensorflow:global_step/sec: 643.774
# INFO:tensorflow:loss = 6.31369, step = 1201 (0.155 sec)
# INFO:tensorflow:global_step/sec: 683.19
# INFO:tensorflow:loss = 6.25031, step = 1301 (0.146 sec)
# INFO:tensorflow:global_step/sec: 659.175
# INFO:tensorflow:loss = 6.12264, step = 1401 (0.152 sec)
# INFO:tensorflow:global_step/sec: 639.152
# INFO:tensorflow:loss = 6.05362, step = 1501 (0.157 sec)
# INFO:tensorflow:global_step/sec: 679.921
# INFO:tensorflow:loss = 5.98407, step = 1601 (0.147 sec)
# INFO:tensorflow:global_step/sec: 646.045
# INFO:tensorflow:loss = 5.91281, step = 1701 (0.155 sec)
# INFO:tensorflow:global_step/sec: 597.54
# INFO:tensorflow:loss = 5.8398, step = 1801 (0.167 sec)
# INFO:tensorflow:global_step/sec: 613.715
# INFO:tensorflow:loss = 5.76542, step = 1901 (0.163 sec)
# INFO:tensorflow:global_step/sec: 675.006
# INFO:tensorflow:loss = 5.6901, step = 2001 (0.148 sec)
# INFO:tensorflow:global_step/sec: 680.379
# INFO:tensorflow:loss = 5.61442, step = 2101 (0.147 sec)
# INFO:tensorflow:global_step/sec: 655.032
# INFO:tensorflow:loss = 5.53907, step = 2201 (0.153 sec)
# INFO:tensorflow:global_step/sec: 691.429
# INFO:tensorflow:loss = 5.46481, step = 2301 (0.145 sec)
# INFO:tensorflow:global_step/sec: 689.157
# INFO:tensorflow:loss = 5.39248, step = 2401 (0.145 sec)
# INFO:tensorflow:global_step/sec: 667.69
# INFO:tensorflow:loss = 5.32288, step = 2501 (0.150 sec)
# INFO:tensorflow:global_step/sec: 683.532
# INFO:tensorflow:loss = 5.25683, step = 2601 (0.146 sec)
# INFO:tensorflow:global_step/sec: 667.396
# INFO:tensorflow:loss = 5.19494, step = 2701 (0.150 sec)
# INFO:tensorflow:global_step/sec: 666.267
# INFO:tensorflow:loss = 5.1378, step = 2801 (0.150 sec)
# INFO:tensorflow:global_step/sec: 681.357
# INFO:tensorflow:loss = 5.08569, step = 2901 (0.146 sec)
# INFO:tensorflow:global_step/sec: 659.417
# INFO:tensorflow:loss = 5.03898, step = 3001 (0.152 sec)
# INFO:tensorflow:global_step/sec: 667.298
# INFO:tensorflow:loss = 4.99771, step = 3101 (0.150 sec)
# INFO:tensorflow:global_step/sec: 672.088
# INFO:tensorflow:loss = 4.96104, step = 3201 (0.148 sec)
# INFO:tensorflow:global_step/sec: 663.9
# INFO:tensorflow:loss = 4.92937, step = 3301 (0.151 sec)
# INFO:tensorflow:global_step/sec: 693.789
# INFO:tensorflow:loss = 4.90213, step = 3401 (0.144 sec)
# INFO:tensorflow:global_step/sec: 669.362
# INFO:tensorflow:loss = 4.87932, step = 3501 (0.150 sec)
# INFO:tensorflow:global_step/sec: 583.621
# INFO:tensorflow:loss = 4.86009, step = 3601 (0.171 sec)
# INFO:tensorflow:global_step/sec: 629.905
# INFO:tensorflow:loss = 4.84356, step = 3701 (0.158 sec)
# INFO:tensorflow:global_step/sec: 662.09
# INFO:tensorflow:loss = 4.82979, step = 3801 (0.151 sec)
# INFO:tensorflow:global_step/sec: 643.364
# INFO:tensorflow:loss = 4.81743, step = 3901 (0.156 sec)
# INFO:tensorflow:global_step/sec: 658.197
# INFO:tensorflow:loss = 4.80734, step = 4001 (0.152 sec)
# INFO:tensorflow:global_step/sec: 616.949
# INFO:tensorflow:loss = 4.79908, step = 4101 (0.162 sec)
# INFO:tensorflow:global_step/sec: 643.786
# INFO:tensorflow:loss = 4.79237, step = 4201 (0.155 sec)
# INFO:tensorflow:global_step/sec: 666.024
# INFO:tensorflow:loss = 4.78681, step = 4301 (0.150 sec)
# INFO:tensorflow:global_step/sec: 653.509
# INFO:tensorflow:loss = 4.78199, step = 4401 (0.153 sec)
# INFO:tensorflow:global_step/sec: 675.443
# INFO:tensorflow:loss = 4.7779, step = 4501 (0.148 sec)
# INFO:tensorflow:global_step/sec: 642.645
# INFO:tensorflow:loss = 4.77424, step = 4601 (0.156 sec)
# INFO:tensorflow:global_step/sec: 672.853
# INFO:tensorflow:loss = 4.77097, step = 4701 (0.149 sec)
# INFO:tensorflow:global_step/sec: 629.894
# INFO:tensorflow:loss = 4.76797, step = 4801 (0.159 sec)
# INFO:tensorflow:global_step/sec: 668.422
# INFO:tensorflow:loss = 4.7654, step = 4901 (0.150 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmprLAnz7/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.76305.
# INFO:tensorflow:Starting evaluation at 2017-07-19-22:36:02
# INFO:tensorflow:Restoring parameters from /tmp/tmprLAnz7/model.ckpt-5000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-07-19-22:36:02
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 5.49714, rmse = 2.3446
# Loss: 5.49714
# Root Mean Squared Error: 2.3446
# WARNING:tensorflow:From <ipython-input-4-6f9e45ff08b8>:29: calling predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from /tmp/tmprLAnz7/model.ckpt-5000
# Prediction 1: 4.69094
# Prediction 2: 10.6595
# Prediction 3: 7.43063
# Prediction 4: 10.921
# Prediction 5: 10.9878
# Prediction 6: 9.46817
# Prediction 7: 11.3105
